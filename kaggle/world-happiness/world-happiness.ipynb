# %% [markdown]
# # World Happiness Report (2019)

# %%
import numpy as np
# Setup imports
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the data into a DataFrame
df = pd.read_csv("2019.csv")

# Preview the first 10 rows
df.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
# Check to see the data type of the columsn and check for nulls
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# Get the distribution of each feature
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(20, 20))

target_column = "Score"

som = {
    0: "",
    1: "",
    2: "",
    3: "",
    4: "",
    5: "",
}

print(som.keys())

print(axes)

# for i in np.array(axes):
#     print(axes[i])

# GDP
# df.plot(kind='scatter', x='GDP per capita', y=target_column, ax=axes[0, 0], title='GDP per capita vs. Score')

# df.plot(kind='scatter', x='Social support', y=target_column, ax=axes[0, 1], title='Social support vs. Score')
# axes[0, 0].legend(loc="upper right")

# 
# df2 = df.drop(columns="Overall rank")
# 
# target_column = "Score"
# 
# print(type(df2))
# 
# for i, column in enumerate(df2.columns):
#     if column == target_column or column == "Country or region":
#         continue
#     
#     df2.plot(kind='scatter', x=column, y=target_column, ax=axes[i])

# plt.tight_layout()
# plt.show()
# Out:
# dict_keys([0, 1, 2, 3, 4, 5])
# [[<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]]
